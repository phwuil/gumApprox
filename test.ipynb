# %%
# %load_ext autoreload
# %autoreload 2

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

import pyAgrum as gum
bn=gum.loadBN("data/alarm.bif")
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pyAgrum.lib.notebook as gnb
gnb.showBN(bn,size="15")
# Out:
# <svg height="764pt" viewBox="0.00 0.00 1023.34 764.00" width="1023pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
# <g class="graph" id="graph0" transform="scale(1 1) rotate(0) translate(4 760)">
# <title>G</title>
# <polygon fill="white" points="-4,4 -4,-760 1019.34,-760 1019.34,4 -4,4" stroke="none"/>
# <!-- HISTORY -->
# <g class="node" id="node1"><title>HISTORY</title>
# <g id="a_node1"><a xlink:title="(0) HISTORY">
# <ellipse cx="48.7457" cy="-162" fill="#444444" rx="48.9926" ry="18" stroke="black"/>
# <text fill="#ffffff" font-family="Times,serif" font-size="14.00" text-anchor="middle" x="48.7457" y="-158.3">HISTORY</text>
# </a>
# </g>
# </g>
# <!-- CVP -->
# <g class="node" id="node2"><title>CVP</title>
# <g id="a_node2"><a xlink:title="(1) CVP">
# <ellipse cx="147.746" cy="-90" fill="#444444" rx="27.8951" ry="18" stroke="black"/>
# ...

# %%
from ApproxInference.utils import conditionalModel

# %%
evs={"SAO2":2,"CATECHOL":1,"MINVOLSET":0}
bn2,evs2=conditionalModel(bn,evs)
gnb.sideBySide(gnb.getInference(bn,evs=evs,size='15'),
               gnb.getInference(bn2,evs=evs2,size='15'))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><img style="margin:0" src="...

# %%
gnb.sideBySide(gnb.getPotential(bn2.cpt("CO")),
               gnb.getPotential(bn.cpt("CO")))
# Out:
# <table style="border-style: hidden; border-collapse: collapse;" width="100%"><tr><td style="border-top:hidden;border-bottom:hidden;"><div align="center"><table>
# <tr><th colspan='2'></th><th colspan='3' style='background-color:#AAAAAA'><center>CO</center></th></tr>
# <tr>
# <th style='background-color:#AAAAAA'><center>HR</center></th>
# <th style='background-color:#AAAAAA'><center>STROKEVOLUME</center></th>
# <th style='background-color:#BBBBBB'><center>LOW</center></th>
# <th style='background-color:#BBBBBB'><center>NORMAL</center></th>
# <th style='background-color:#BBBBBB'><center>HIGH</center></th>
# <tr>
# <th style='background-color:#BBBBBB;' rowspan = '3'>LOW</th>
# <th style='background-color:#BBBBBB'>LOW</th>
# <td style='text-align:right;'>0.9800</td>
# <td style='text-align:right;'>0.0100</td>
# <td style='text-align:right;'>0.0100</td>
# </tr><tr>
# <th style='background-color:#BBBBBB'>NORMAL</th>
# <td style='text-align:right;'>0.9500</td>
# ...

# %%
p=bn.cpt("CO").extract({"STROKEVOLUME":2})
gnb.showPotential(p)
# Out:
# <table><tr><th colspan='1'></th><th colspan='3' style='background-color:#AAAAAA'><center>CO</center></th></tr><tr><th style='background-color:#AAAAAA'><center>HR</center></th><th style='background-color:#BBBBBB'><center>LOW</center></th><th style='background-color:#BBBBBB'><center>NORMAL</center></th><th style='background-color:#BBBBBB'><center>HIGH</center></th><tr><th style='background-color:#BBBBBB'>LOW</th><td style='text-align:right;'>0.3000</td><td style='text-align:right;'>0.6900</td><td style='text-align:right;'>0.0100</td></tr><tr><th style='background-color:#BBBBBB'>NORMAL</th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.3000</td><td style='text-align:right;'>0.6900</td></tr><tr><th style='background-color:#BBBBBB'>HIGH</th><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.0100</td><td style='text-align:right;'>0.9800</td></tr></table>

# %%
p.reorganize(["HR","CO"])
# Out:
# <pyAgrum.pyAgrum.Potential_double; proxy of <Swig Object of type 'gum::Potential< double > *' at 0x7f2448528720> >

# %%
p=bn.cpt("CO")

# %%
p.
